# %%
import pandas as pd 
import requests
import re
import math
from collections import Counter
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
######################## HELPER FUNCTIONS ##################################

def text_to_vector(text):
    WORD = re.compile(r"\w+")
    words = WORD.findall(text)
    return Counter(words)

def get_cosine(vec1, vec2):
    intersection = set(vec1.keys() & vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x] ** 2 for x in list(vec1.keys())])
    sum2 = sum([vec2[x] ** 2 for x in list(vec2.keys())])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

def possible_replacement_api(missing_api:str, answer_body: str) -> str:
    # done via cosine similarity method
    soup = BeautifulSoup(answer_body, "html.parser")
    candidate_apis = [link.get_text() for link in soup.select("code")]
    missing_api_vector = text_to_vector(missing_api)
    cosine_dict = {}
    if len(candidate_apis) > 1:
        for candidate in candidate_apis:
            candidate_vector = text_to_vector(candidate)
            cosine_similarity = get_cosine(missing_api_vector, candidate_vector)
            cosine_dict[candidate] = cosine_similarity
        return min(cosine_dict, key=cosine_dict.get)
    elif len(candidate_apis) == 1:
        return candidate_apis[0]

# %%
def getStackQuestions(missing_api:str) -> pd.DataFrame:
    questionQueryURL = "https://api.stackexchange.com/2.3/search/advanced?"
    answerQueryURL = "https://api.stackexchange.com/2.3/questions/{}/answers?"
    questionfilter_dict = {
        "body" : missing_api,
        "sort": "votes",
        "order": "desc",
        "site": "stackoverflow",
        "filter" : "!0WAfAKLVhyg2Bjytoa)ZVCaM5"
    }
    questionAnswersFilter = {
        "order": "desc",
        "sort": "votes",
        "site": "stackoverflow",
        "filter": "!3ubsrEfVBpYHFpKQ5"
    }
    for key, value in questionfilter_dict.items():
        questionQueryURL += "{}={}&".format(key, value)
    ## slice the last element away
    questionQueryURL = questionQueryURL[:-1]
    # for the answers portion
    for key, value in questionAnswersFilter.items():
        answerQueryURL += "{}={}&".format(key, value)
    answerQueryURL = answerQueryURL[:-1]
    # get request
    r = requests.get(questionQueryURL)
    data = r.json()
    questionArr = data["items"]
    # filter away the not answered question
    filteredArr = []
    if len(questionArr) == 0:
        return []
    
    # accept top 1 answers
    for question in questionArr:
        if question["is_answered"]:
            answerURL = answerQueryURL.format(question["question_id"])
            response = requests.get(answerURL)
            answerData = response.json()["items"][0]
            question["answer_score"] = answerData["score"]
            question["answer_body"] = answerData["body"]
            filteredArr.append(question)
    
    df = pd.json_normalize(filteredArr)
    df["possible_replacement"] = df["answer_body"].apply(lambda x: possible_replacement_api(missing_api,x))
    return df

# %% [markdown]
# get 5 replacements

# %%
df = getStackQuestions("sklearn.externals.joblib")
df
# Out:
#    is_answered  view_count  answer_count  score  last_activity_date  \
# 0         True       16215             4      6          1645303395
# 1         True         753             1      3          1638282046
# 2         True         545             1      0          1531388579
#
#    creation_date  question_id  \
# 0     1557755770     56113916
# 1     1638242427     70163883
# 2     1524115667     49913330
#
#                                                 link  \
# 0  https://stackoverflow.com/questions/56113916/c...
# 1  https://stackoverflow.com/questions/70163883/g...
# 2  https://stackoverflow.com/questions/49913330/e...
#
#                                                title  \
# 0  Cannot import Sklearn from sklearn.externals.j...
# 1  Google Colab ModuleNotFoundError: No module na...
# 2  Export KNN best estimator from GridSearchCV to...
#
#                                                 body  answer_score  \
# 0  <p>I am a beginner and I just started with mac...            10
# 1  <p>My Initial import looks like this and this ...             5
# 2  <p>I tried to save <strong>KNN</strong> model ...             1
#
#                                          answer_body  accepted_answer_id  \
# 0  <p>I had the same problem.\nI have replaced</p...                 NaN
# 1  <p>For the second part you can do this to fix ...          70163925.0
# 2  <p>According to documentation:</p>\n\n<pre><co...                 NaN
#
#                                 possible_replacement
# 0                                      import joblib
# 1  # Libraries to help with reading and manipulat...
# 2  n_neighbors : int, optional (default = 5)\n\n ...

# %% [markdown]
# Test out on sklearn data

# %%
scipy_df = pd.read_csv("Labeling - scipy.csv")
scipy_df
# Out:
#                 deprecated API        replacement API  \
# 0                   scipy.rand      numpy.random.rand
# 1                   scipy.diag             numpy.diag
# 2    scipy.interpolate.splmake                    NaN
# 3    scipy.interpolate.spltopp                    NaN
# 4    scipy.interpolate.spleval                    NaN
# ..                         ...                    ...
# 102         scipy.linalg.expm2      scipy.linalg.expm
# 103         scipy.linalg.expm3      scipy.linalg.expm
# 104         scipy.stats.oneway   scipy.stats.f_oneway
# 105            scipy.stats.glm  scipy.stats.ttest_ind
# 106        scipy.stats.cmedian           numpy.median
#
#     official documentation (web)?  available in rel notes  REPLACEMENT_FOUND  \
# 0                               0                     1.0                1.0
# 1                0.5? placeholder                     1.0                1.0
# 2                               0                     0.0                1.0
# 3                               0                     0.0                0.0
# 4                               0                     0.0                0.0
# ..                            ...                     ...                ...
# 102                           NaN                     1.0                1.0
# 103                           NaN                     1.0                1.0
# 104                           NaN                     1.0                1.0
# 105                           NaN                     1.0                1.0
# 106                           NaN                     1.0                1.0
#
#      CORRECT replacement ?       Proposed replacement  \
# 0                      0.0              ['scipy.fft']
# 1                      0.0              ['scipy.fft']
# 2                      0.0        ['splmake/spleval']
# 3                      0.0                        NaN
# 4                      0.0                        NaN
# ..                     ...                        ...
# 102                    1.0      ['scipy.linalg.expm']
# 103                    1.0      ['scipy.linalg.expm']
# 104                    1.0   ['scipy.stats.f_oneway']
# 105                    1.0  ['scipy.stats.ttest_ind']
# 106                    1.0           ['numpy.median']
#
#      official documentation (code)? Stack Overflow?   \
# 0                               1.0                0
# 1                               1.0                0
# 2                               1.0                0
# 3                               1.0                0
# 4                               1.0                0
# ..                              ...              ...
# 102                             0.0              NaN
# 103                             0.0              NaN
# 104                             0.0              NaN
# 105                             0.0              NaN
# 106                             1.0              NaN
#
#     Remarks (why missing, anything interesting,What if there is more than 1 replacement?)  \
# 0    function still exist in newest ver. just depre...
# 1    function still exist in newest ver. just depre...
# 2    no replacement is mentioned in the official do...
# 3    stackoverflow: spltopp, 1 result, no replaceme...
# 4    stackoverflow: spleval, 13 result, no replacem...
# ..                                                 ...
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
#
#      To label
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 102       NaN
# 103       NaN
# 104       NaN
# 105       NaN
# 106       NaN
#
# [107 rows x 11 columns]

# %%
scipy_depre_apis = scipy_df["deprecated API"].to_list()
scipy_depre_apis
# Out:
# ['scipy.rand',
#  'scipy.diag',
#  'scipy.interpolate.splmake',
#  'scipy.interpolate.spltopp',
#  'scipy.interpolate.spleval',
#  'scipy.interpolate.spline',
#  'scipy.interpolate.interpolate_wrapper',
#  'scipy.misc.bytescale',
#  'scipy.misc.fromimage',
#  'scipy.misc.imfilter',
#  'scipy.misc.imread',
#  'scipy.misc.imresize',
#  'scipy.misc.imrotate',
#  'scipy.misc.imsave',
#  'scipy.misc.imshow',
#  'scipy.misc.toimage',
#  'scipy.misc.comb',
#  'scipy.misc.factorial',
#  'scipy.misc.factorial2',
#  'scipy.misc.factorialk',
#  'scipy.misc.logsumexp',
#  'scipy.misc.pade',
#  'scipy.misc.info',
#  'scipy.misc.source',
#  'scipy.misc.who',
#  'scipy.special.hyp2f0',
#  'scipy.special.hyp1f2',
#  'scipy.special.hyp3f0',
#  'scipy.signal.windows.slepian',
#  'scipy.stats.itemfreq',
#  'scipy.spatial.distance.matching',
#  'scipy.spatial.distance.wminkowski',
#  'scipy.special.errprint',
#  'scipy.special.sph_in',
#  'scipy.special.sph_jn',
#  'scipy.special.sph_kn',
#  'scipy.special.sph_yn',
#  'scipy.special.sph_jnyn',
#  'scipy.special.sph_inkn',
#  'scipy.constants.C2K',
#  'scipy.constants.K2C',
#  'scipy.constants.C2F',
#  'scipy.constants.F2C',
#  'scipy.constants.F2K',
#  'scipy.constants.K2F',
#  'scipy.stats.histogram',
#  'scipy.stats.threshold',
#  'scipy.mstats.threshold',
#  'scipy.stats.ss',
#  'scipy.stats.square_of_sums',
#  'scipy.stats.chisqprob',
#  'scipy.stats.f_value',
#  'scipy.stats.f_value_multivariate',
#  'scipy.stats.f_value_wilks_lambda',
#  'scipy.mstats.f_value_wilks_lambda',
#  'scipy.stats.betai',
#  'scipy.stats.pdf_fromgamma',
#  'scipy.stats.fastsort',
#  'scipy.stats.signaltonoise',
#  'scipy.stats.histogram2',
#  'scipy.signal.hanning',
#  'scipy.signal.slepian',
#  'scipy.signal',
#  'scipy.misc.docformat',
#  'scipy.misc.inherit_docstring_from',
#  'scipy.misc.extend_notes_in_docstring',
#  'scipy.misc.replace_notes_in_docstring',
#  'scipy.misc.indentcount_lines',
#  'scipy.misc.filldoc',
#  'scipy.misc.unindent_dict',
#  'scipy.misc.unindent_string',
#  'scipy._ppform',
#  'scipy.stats.frechet_r',
#  'scipy.stats.frechet_l',
#  'scipy.special.basic',
#  'scipy.spatial.Rotation.match_vectors',
#  'scipy.spatial.transform.Rotation.as_dcm',
#  'scipy.spatial.transform.Rotation.match_vectors',
#  'scipy.spatial.distance.matching',
#  'scipy.sparse.sparsetools',
#  'scipy.sparse.bsr_matrix.matvec',
#  'scipy.sparse.bsr_matrix.matmat',
#  'scipy.signal.firwin:nyq',
#  'scipy.signal.firwin2:nyq',
#  'scipy.signal.remez:Hz',
#  'scipy.signal.firls:nyq',
#  'scipy.linalg.solve:sym_pos, debug',
#  'scipy.linalg.solve_triangular:debug',
#  'scipy.linalg.solve_banded:debug',
#  'scipy.interpolate.splprep:quiet',
#  'scipy.interpolate.splrep:quiet',
#  'scipy.interpolate.bisplrep:quiet',
#  'scipy._PPolyBase.extend:right',
#  'scipy.stats.rv_continuous:extradoc',
#  'scipy.stats.kendalltau:initial_lexsort',
#  'scipy.spatial.transform.Rotation.from_quat:normalized',
#  'scipy.spatial.distance.pdist:*args,old_cosine',
#  'scipy.spatial.distance.cdist:*args',
#  'scipy.spatial.Delaunay:vertices',
#  'scipy._minimize_neldermead:unknown_options,ftol,xtol',
#  'scipy._dendrogram_calculate_info:truncate_mode',
#  'scipy.sparse.linalg.gmres:restrt',
#  'scipy.linalg.expm2',
#  'scipy.linalg.expm3',
#  'scipy.stats.oneway',
#  'scipy.stats.glm',
#  'scipy.stats.cmedian']

# %%
# filter out parameter and function deprecated apis
scipy_depre_function_apis = []
scipy_depre_param_apis = []
for api in scipy_depre_apis:
    if ":" in api:
        scipy_depre_param_apis.append(api)
    else:
        scipy_depre_function_apis.append(api)
print("Length of function deprec api:", len(scipy_depre_function_apis))
print("Length of param depre api:", len(scipy_depre_param_apis))
# Out:
# Length of function deprec api: 87
# Length of param depre api: 20

# %%
def getStackQuestionsv2(missing_api:str, top_only:bool) -> pd.DataFrame:
    questionQueryURL = "https://api.stackexchange.com/2.3/search/advanced?"
    answerQueryURL = "https://api.stackexchange.com/2.3/questions/{}/answers?"
    questionfilter_dict = {
        "body" : missing_api,
        "sort": "votes",
        "order": "desc",
        "site": "stackoverflow",
        "filter" : "!0WAfAKLVhyg2Bjytoa)ZVCaM5"
    }
    questionAnswersFilter = {
        "order": "desc",
        "sort": "votes",
        "site": "stackoverflow",
        "filter": "!3ubsrEfVBpYHFpKQ5"
    }
    for key, value in questionfilter_dict.items():
        questionQueryURL += "{}={}&".format(key, value)
    ## slice the last element away
    questionQueryURL = questionQueryURL[:-1]
    # for the answers portion
    for key, value in questionAnswersFilter.items():
        answerQueryURL += "{}={}&".format(key, value)
    answerQueryURL = answerQueryURL[:-1]
    # get request
    r = requests.get(questionQueryURL)
    data = r.json()
    questionArr = data["items"]
    # filter away the not answered question
    filteredArr = []
    # return empty string if there is no related question found
    if len(questionArr) == 0:
        return ""
    else:
        # accept top 1 answers
        for question in tqdm(questionArr):
            if question["is_answered"]:
                answerURL = answerQueryURL.format(question["question_id"])
                response = requests.get(answerURL)
                if len(response.json()["items"]) == 0:
                    continue
                answerData = response.json()["items"][0]
                question["answer_score"] = answerData["score"]
                question["answer_body"] = answerData["body"]
                filteredArr.append(question)
    
        df = pd.json_normalize(filteredArr)
        df["possible_replacement"] = df["answer_body"].apply(lambda x: possible_replacement_api(missing_api,x))
        if top_only:
            top_candidate = list(df["possible_replacement"])[0]
            return top_candidate
        else:
            return df

# %%
getStackQuestionsv2("sklearn.externals.joblib", True)
# Out:
# 100%|██████████| 6/6 [00:03<00:00,  1.95it/s]
# 'import joblib'

# %%
# intialise replacement dictionary
scipy_replacement_dict = {}
for api in scipy_depre_function_apis:
    scipy_replacement_dict[api] = getStackQuestionsv2(api, True)
scipy_replacement_dict
# Out:
# 100%|██████████| 4/4 [00:03<00:00,  1.28it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# 100%|██████████| 16/16 [00:12<00:00,  1.27it/s]
# 100%|██████████| 6/6 [00:04<00:00,  1.44it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'answer_body'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15624/2868414557.py in <module>
#       2 scipy_replacement_dict = {}
#       3 for api in scipy_depre_function_apis:
# ----> 4     scipy_replacement_dict[api] = getStackQuestionsv2(api, True)
#       5 scipy_replacement_dict
#
# ~\AppData\Local\Temp/ipykernel_15624/782087615.py in getStackQuestionsv2(missing_api, top_only)
#      46
#      47         df = pd.json_normalize(filteredArr)
# ---> 48         df["possible_replacement"] = df["answer_body"].apply(lambda x: possible_replacement_api(missing_api,x))
#      49         if top_only:
#      50             top_candidate = list(df["possible_replacement"])[0]
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'answer_body'

# %%
scipy_replacement_dict
# Out:
# {'scipy.rand': '',
#  'scipy.diag': '',
#  'scipy.interpolate.splmake': '',
#  'scipy.interpolate.spltopp': '',
#  'scipy.interpolate.spleval': '',
#  'scipy.interpolate.spline': 'import shapely.geometry as shgeo\nline = vstack( (x,y) ).T\nline = shgeo.LineString( line )\nsurrounding_polygon = line.buffer( 10,cap_style=3 ) # 10=Dist\n',
#  'scipy.interpolate.interpolate_wrapper': '',
#  'scipy.misc.bytescale': '',
#  'scipy.misc.fromimage': 'cdist',
#  'scipy.misc.imfilter': '',
#  'scipy.misc.imread': 'multiprocessing.Pool',
#  'scipy.misc.imresize': 'import skimage\ndata_new = skimage.transform.resize(data_old, [new_shape_x, new_shape_z], order = 0)\n'}
